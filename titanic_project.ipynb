# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
print(train.shape)
print(test.shape)
# Out:
# (891, 12)
# (418, 11)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB

# %%
train.drop(columns=['Cabin'],inplace=True)
test.drop(columns=['Cabin'],inplace=True)

# %%
train.sample()
# Out:
#      PassengerId  Survived  Pclass  \
# 416          417         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 416  Drew, Mrs. James Vivian (Lulu Thorne Christian)  female  34.0      1
#
#      Parch Ticket  Fare Embarked
# 416      1  28220  32.5        S

# %%
test.sample()
# Out:
#      PassengerId  Pclass                       Name   Sex   Age  SibSp  Parch  \
# 279         1171       2  Oxenham, Mr. Percy Thomas  male  22.0      0      0
#
#           Ticket  Fare Embarked
# 279  W./C. 14260  10.5        S

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId     0
# Pclass          0
# Name            0
# Sex             0
# Age            86
# SibSp           0
# Parch           0
# Ticket          0
# Fare            1
# Embarked        0
# dtype: int64

# %%
train['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
train['Embarked'].fillna('S',inplace=True)
# Out:
# C:\Users\sanke\AppData\Local\Temp\ipykernel_23884\535005595.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train['Embarked'].fillna('S',inplace=True)

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# dtype: int64

# %%
test['Fare'].fillna(test['Fare'].mean(),inplace=True)
# Out:
# C:\Users\sanke\AppData\Local\Temp\ipykernel_23884\3411113445.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test['Fare'].fillna(test['Fare'].mean(),inplace=True)

# %%
test.isnull().sum()
# Out:
# PassengerId     0
# Pclass          0
# Name            0
# Sex             0
# Age            86
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Embarked        0
# dtype: int64

# %%
train_age = np.random.randint(train['Age'].mean()-train['Age'].std(),train['Age'].mean()+train['Age'].std(),177)

# %%
test_age = np.random.randint(test['Age'].mean()-test['Age'].std(),test['Age'].mean()+test['Age'].std(),86)

# %%
train['Age'][train['Age'].isnull()]=train_age
# Out:
# C:\Users\sanke\AppData\Local\Temp\ipykernel_23884\4268069075.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   train['Age'][train['Age'].isnull()]=train_age
# ...

# %%
train.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
test['Age'][test['Age'].isnull()]=test_age
test.isnull().sum()
# Out:
# C:\Users\sanke\AppData\Local\Temp\ipykernel_23884\1099523540.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   test['Age'][test['Age'].isnull()]=test_age
# ...

# %%
#EDA
train.groupby(['Pclass'])['Survived'].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
119/(372+119)
# Out:
# 0.24236252545824846

# %%
train.groupby(['Sex'])['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
train.groupby(['Embarked'])['Survived'].mean()
# Out:
# Embarked
# C    0.553571
# Q    0.389610
# S    0.339009
# Name: Survived, dtype: float64

# %%
sns.distplot(train['Age'])
# Out:
# C:\Users\sanke\AppData\Local\Temp\ipykernel_23884\1463015962.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(train['Age'][train['Survived']==0])
sns.distplot(train['Age'][train['Survived']==1])
# Out:
# C:\Users\sanke\AppData\Local\Temp\ipykernel_23884\3826302481.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train['Age'][train['Survived']==0])
# C:\Users\sanke\AppData\Local\Temp\ipykernel_23884\3826302481.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.distplot(train['Fare'][train['Survived']==0])
sns.distplot(train['Fare'][train['Survived']==1])
# Out:
# C:\Users\sanke\AppData\Local\Temp\ipykernel_23884\2626582821.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train['Fare'][train['Survived']==0])
# C:\Users\sanke\AppData\Local\Temp\ipykernel_23884\2626582821.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
train.drop(columns=['Ticket'],inplace=True)
test.drop(columns=['Ticket'],inplace=True)

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch     Fare Embarked
# 0  34.5      0      0   7.8292        Q
# 1  47.0      1      0   7.0000        S
# 2  62.0      0      0   9.6875        Q
# 3  27.0      0      0   8.6625        S
# 4  22.0      1      1  12.2875        S

# %%
train['Family'] = train['SibSp'] + train['Parch']+1

# %%
test['Family'] = test['SibSp'] + test['Parch']+1

# %%
train['Family'].value_counts()
# Out:
# Family
# 1     537
# 2     161
# 3     102
# 4      29
# 6      22
# 5      15
# 7      12
# 11      7
# 8       6
# Name: count, dtype: int64

# %%
train.groupby(['Family'])['Survived'].mean()
# Out:
# Family
# 1     0.303538
# 2     0.552795
# 3     0.578431
# 4     0.724138
# 5     0.200000
# 6     0.136364
# 7     0.333333
# 8     0.000000
# 11    0.000000
# Name: Survived, dtype: float64

# %%
def cal(num):
    if num==1:
        return "Alone"
    elif num>1 and num<5:
        return "Medium"
    else:
        return "Large"

# %%
train['Familiy_size'] = train['Family'].apply(cal)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Embarked  Family Familiy_size
# 0      0   7.2500        S       2       Medium
# 1      0  71.2833        C       2       Medium
# 2      0   7.9250        S       1        Alone
# 3      0  53.1000        S       2       Medium
# 4      0   8.0500        S       1        Alone

# %%
test['Familiy_size'] = test['Family'].apply(cal)

# %%
train.drop(columns=['SibSp','Parch','Family'],inplace=True)
test.drop(columns=['SibSp','Parch','Family'],inplace=True)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age     Fare  \
# 0                            Braund, Mr. Owen Harris    male  22.0   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0  71.2833
# 2                             Heikkinen, Miss. Laina  female  26.0   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  53.1000
# 4                           Allen, Mr. William Henry    male  35.0   8.0500
#
#   Embarked Familiy_size
# 0        S       Medium
# 1        C       Medium
# 2        S        Alone
# 3        S       Medium
# 4        S        Alone

# %%
passengerId = test['PassengerId'].values

# %%
train.drop(columns=['PassengerId','Name'],inplace=True)
test.drop(columns=['PassengerId','Name'],inplace=True)

# %%
train.isnull().sum()
# Out:
# Survived        0
# Pclass          0
# Sex             0
# Age             0
# Fare            0
# Embarked        0
# Familiy_size    0
# dtype: int64

# %%
train.shape
# Out:
# (891, 7)

# %%
train = pd.get_dummies(train,columns=['Pclass','Sex','Familiy_size','Embarked'],drop_first=True)

# %%
train.shape
# Out:
# (891, 10)

# %%
test = pd.get_dummies(test,columns=['Pclass','Sex','Familiy_size','Embarked'],drop_first=True)

# %%
test.shape
# Out:
# (418, 9)

# %%
train
# Out:
#      Survived   Age     Fare  Pclass_2  Pclass_3  Sex_male  \
# 0           0  22.0   7.2500     False      True      True
# 1           1  38.0  71.2833     False     False     False
# 2           1  26.0   7.9250     False      True     False
# 3           1  35.0  53.1000     False     False     False
# 4           0  35.0   8.0500     False      True      True
# ..        ...   ...      ...       ...       ...       ...
# 886         0  27.0  13.0000      True     False      True
# 887         1  19.0  30.0000     False     False     False
# 888         0  19.0  23.4500     False      True     False
# 889         1  26.0  30.0000     False     False      True
# 890         0  32.0   7.7500     False      True      True
#
#      Familiy_size_Large  Familiy_size_Medium  Embarked_Q  Embarked_S
# 0                 False                 True       False        True
# 1                 False                 True       False       False
# ...

# %%
X = train.iloc[:,1:].values
y = train.iloc[:,0].values

# %%
from sklearn.model_selection import train_test_split as tts
X_train,X_test,y_train,y_test = tts(X,y,test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()

# %%
classifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.7988826815642458

# %%
Xf=test.iloc[:,:].values

# %%
y_final = classifier.predict(Xf)

# %%
y_final.shape
# Out:
# (418,)

# %%
passengerId.shape
# Out:
# (418,)

# %%
final = pd.DataFrame()
final
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
final['passengerId'] = passengerId
final['survived'] = y_final

# %%
final
# Out:
#      passengerId  survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         1
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         1
#
# [418 rows x 2 columns]

# %%
final.to_csv('submit.csv',index=False)

# %%
submit = pd.read_csv('submit.csv')
submit.head()
# Out:
#    passengerId  survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         1
# 4          896         0
